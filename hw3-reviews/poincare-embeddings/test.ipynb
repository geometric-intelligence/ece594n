# %%
from geomstats import backend as gs
from geomstats.geometry.poincare_ball import PoincareBall, PoincareBallMetric

print(os.environ["GEOMSTATS_BACKEND"])
print(type(gs.array(0)))

import matplotlib.pyplot as plt
# %matplotlib inline
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from tqdm.notebook import tqdm
from nltk.corpus import wordnet as wn
import os




SEED = 42
EPS = 1e-5
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

target = wn.synset('mammal.n.01')
words = wn.words()

manifold = PoincareBall(2)
metric = PoincareBallMetric(2)
# Out:
# INFO: Using pytorch backend
# pytorch
# <class 'torch.Tensor'>

# %%
nouns = set()
for word in words:
    nouns.update(wn.synsets(word, pos='n'))

print(len(nouns), 'nouns')

hypernyms = []
for noun in nouns:
    paths = noun.hypernym_paths()
    for path in paths:
        try:
            pos = path.index(target)
            for i in range(pos, len(path)-1):
                hypernyms.append((noun, path[i]))
        except Exception:
            continue
            
hypernyms = np.array(list(set(hypernyms)))
uniq_hypernyms = np.array(list(set([e for tup in hypernyms for e in tup])))

word2idx = {val: i for i, val in enumerate(uniq_hypernyms)}
random.shuffle(hypernyms)

print(len(hypernyms), 'hypernyms' )
# Out:
# 82115 nouns
# 6542 hypernyms

# %%
def proj(params):
    norm = params.norm(p=2, dim=1).unsqueeze(1)
    norm[norm < 1] = 1+EPS
    params = params.div(norm)-EPS
    return params

# def proj(params):
#     return manifold.projection(params)

def arcosh(x):
    result = torch.log(x + torch.sqrt(x**2 - 1))
    print()
    print("Dist")

    print(result.size())
    return result

# def distance(u, v):
#     uu = u.norm(dim=1)**2
#     vv = v.norm(dim=1)**2
#     uv = u.mm(v.t())
#     alpha = 1-uu
#     alpha = alpha.clamp(min=EPS)
#     beta = 1-vv
#     beta = beta.clamp(min=EPS)
    
#     gamma = 1 + 2 * (uu - 2 * uv + vv) / (alpha * beta)
#     gamma = gamma.clamp(min=1+EPS)
    
#     return arcosh(gamma)


def distance(u, v):
    print("Metric\n")
    print(metric.dist(u,v))
    result = metric.dist(u+EPS,v)
    result = torch.reshape(result, [1,-1])
    print(result.grad_fn)
    print(result.size())
    return result
    
def plot():
    lhds, rhds = hypernyms[:, 0], hypernyms[:, 1]

    targets = set(lhd for i, lhd in enumerate(lhds) if rhds[i] == target)
    embeddings = EMBEDDINGS.numpy()

    if len(targets) + 1 > 30:
        targets = random.sample(targets, 30-1)
    targets.append(target)
    
    fig = plt.figure(figsize=(10,10))
    ax = plt.gca()
    ax.cla() # clear things for fresh plot

    ax.set_xlim((-1.1, 1.1))
    ax.set_ylim((-1.1, 1.1))

    circle = plt.Circle((0,0), 1., color='black', fill=False)
    ax.add_artist(circle)

    for n in targets:
        x, y = embeddings[word2idx[n]]
        ax.plot(x, y, 'o', color='y')
        ax.text(x+0.01, y+0.01, n.name(), color='b')
    plt.show()

# %%
EPOCHS = 10
DIM = 2
START_LR = 0.1
FINAL_LR = 0.0001
NEG = 10

EMBEDDINGS = torch.Tensor(len(uniq_hypernyms), DIM)
nn.init.uniform_(EMBEDDINGS, a=-0.001, b=0.001)

NEG_SAMPLES = torch.from_numpy(np.random.randint(0, len(uniq_hypernyms), size=(EPOCHS, len(hypernyms), NEG)))

bar1 = tqdm(range(EPOCHS))
for epoch in bar1:
    plot()
    bar2 = tqdm(hypernyms, leave=False)
    for i, (w1, w2) in enumerate(bar2):
        i_w1 = word2idx[w1]
        i_w2 = word2idx[w2]
        u = Variable(EMBEDDINGS[i_w1].unsqueeze(0), requires_grad=True)
        v = Variable(EMBEDDINGS[i_w2].unsqueeze(0), requires_grad=True)
        negs = Variable(EMBEDDINGS[NEG_SAMPLES[epoch, i]], requires_grad=True)
        print("Loss")
        print(torch.exp(-1*distance(u, negs)))
        print(-1*distance(u, negs))
        print("End loss")
        loss = torch.exp(-1*distance(u, v)) / torch.exp(-1*distance(u, negs)).sum()
        bar2.set_postfix(loss=loss.data[0, 0])
        loss.backward()
        
        r = epoch/EPOCHS
        LR = (1-r) * START_LR + r * FINAL_LR
        EMBEDDINGS[NEG_SAMPLES[epoch, i]] -= LR * (((1-negs.norm(dim=1)**2) ** 2) / 4).data.unsqueeze(1) * negs.grad.data
        EMBEDDINGS[i_w1] -= torch.flatten((LR * (((1-u.norm()**2) **2) / 4).data * u.grad.data))
        EMBEDDINGS[i_w2] -= torch.flatten(LR * (((1-v.norm()**2) **2) / 4).data * v.grad.data)
        
        EMBEDDINGS = proj(EMBEDDINGS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# /tmp/ipykernel_9556/2087030993.py:49: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   targets = random.sample(targets, 30-1)
#   0%|          | 0/6542 [00:00<?, ?it/s]
# Loss
# Metric
#
# tensor([0.0005, 0.0026, 0.0029, 0.0030, 0.0036, 0.0034, 0.0013, 0.0017, 0.0033,
#         0.0022], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bd90>
# torch.Size([1, 10])
# tensor([[0.9995, 0.9974, 0.9971, 0.9970, 0.9964, 0.9966, 0.9987, 0.9983, 0.9967,
#          0.9978]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([0.0024], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bd90>
# torch.Size([1, 1])
# Metric
#
# tensor([0.0005, 0.0026, 0.0029, 0.0030, 0.0036, 0.0034, 0.0013, 0.0017, 0.0033,
#         0.0022], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bd90>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([0.0039, 0.0034, 0.0055, 0.0067, 0.0046, 0.0044, 0.0045, 0.0037, 0.0040,
#         0.0055], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33d649a0>
# torch.Size([1, 10])
# tensor([[0.9962, 0.9967, 0.9945, 0.9934, 0.9954, 0.9956, 0.9956, 0.9964, 0.9961,
#          0.9945]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([0.0147], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33d649a0>
# torch.Size([1, 1])
# Metric
#
# tensor([0.0039, 0.0034, 0.0055, 0.0067, 0.0046, 0.0044, 0.0045, 0.0037, 0.0040,
#         0.0055], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33d649a0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([0.0047, 0.0051, 0.0060, 0.0055, 0.0035, 0.0072, 0.0036, 0.0068, 0.0032,
#         0.0043], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a2588deb0>
# torch.Size([1, 10])
# tensor([[0.9953, 0.9949, 0.9940, 0.9945, 0.9966, 0.9928, 0.9965, 0.9932, 0.9969,
#          0.9958]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([0.0254], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a2588deb0>
# torch.Size([1, 1])
# Metric
#
# tensor([0.0047, 0.0051, 0.0060, 0.0055, 0.0035, 0.0072, 0.0036, 0.0068, 0.0032,
#         0.0043], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a2588deb0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([0.0037, 0.0057, 0.0059, 0.0052, 0.0050, 0.0052, 0.0073, 0.0061, 0.0051,
#         0.0028], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33d649a0>
# torch.Size([1, 10])
# tensor([[0.9963, 0.9943, 0.9941, 0.9948, 0.9950, 0.9948, 0.9928, 0.9939, 0.9950,
#          0.9972]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([0.0356], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33d649a0>
# torch.Size([1, 1])
# Metric
#
# tensor([0.0037, 0.0057, 0.0059, 0.0052, 0.0050, 0.0052, 0.0073, 0.0061, 0.0051,
#         0.0028], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33d649a0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([0.0038, 0.0026, 0.0012, 0.0038, 0.0040, 0.0020, 0.0035, 0.0023, 0.0035,
#         0.0025], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a2588deb0>
# torch.Size([1, 10])
# tensor([[0.9962, 0.9974, 0.9988, 0.9962, 0.9960, 0.9979, 0.9965, 0.9977, 0.9965,
#          0.9975]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([0.
grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[   nan, 0.9987, 0.9984, 0.9983,    nan, 0.9987,    nan, 0.9990, 0.9987,
#          0.9976]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([   nan, 0.0013, 0.0016, 0.0017,    nan, 0.0013,    nan, 0.0010, 0.0014,
#         0.0024], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([0.0014, 0.0019, 0.0020,    nan, 0.0040, 0.0012, 0.0016, 0.0033, 0.0038,
#            nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[0.9985, 0.9981, 0.9981,    nan, 0.9960, 0.9988, 0.9984, 0.9968, 0.9962,
#             nan]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([0.0014, 0.0019, 0.0020,    nan, 0.0040, 0.0012, 0.0016, 0.0033, 0.0038,
#            nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([   nan, 0.0032,    nan, 0.0008, 0.0035,    nan, 0.0043, 0.0045, 0.0026,
#            nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[   nan, 0.9967,    nan, 0.9992, 0.9965,    nan, 0.9958, 0.9955, 0.9974,
#             nan]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([   nan, 0.0032,    nan, 0.0008, 0.0035,    nan, 0.0043, 0.0045, 0.0026,
#            nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([0.0005, 0.0019, 0.0007, 0.0078, 0.0021, 0.0017, 0.0030,    nan, 0.0020,
#         0.0022], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[0.9995, 0.9980, 0.9995, 0.9922, 0.9979, 0.9983, 0.9970,    nan, 0.9980,
#          0.9978]], grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([0.0005, 0.0019, 0.0007, 0.0078, 0.0021, 0.0017, 0.0030,    nan, 0.0020,
#         0.0022], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a32fe8520>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
# ...
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33c7bc70>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 1])
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# Loss
# Metric
#
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        grad_fn=<MulBackward0>)
# <ViewBackward object at 0x7f2a33dbdcd0>
# torch.Size([1, 10])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#        grad_fn=<ExpBackward>)
# Metric
#
# tensor([nan], grad_fn=<MulBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb Cell 4' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000003?line=21'>22</a> print("Loss")
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000003?line=22'>23</a> print(torch.exp(-1*distance(u, negs)))
# ---> <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000003?line=24'>25</a> loss = torch.exp(-1*distance(u, v)) / torch.exp(-1*distance(u, negs)).sum()
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000003?line=25'>26</a> bar2.set_postfix(loss=loss.data[0, 0])
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000003?line=26'>27</a> loss.backward()
#
# /home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb Cell 3' in distance(u, v)
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000002?line=33'>34</a> print("Metric\n")
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000002?line=34'>35</a> print(metric.dist(u,v))
# ---> <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000002?line=35'>36</a> result = metric.dist(u+EPS,v)
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000002?line=36'>37</a> result = torch.reshape(result, [1,-1])
#      <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw3-reviews/poincare-embeddings/test.ipynb#ch0000002?line=37'>38</a> print(result.grad_fn)
#
# File ~/miniconda3/lib/python3.9/site-packages/geomstats/geometry/poincare_ball.py:254, in PoincareBallMetric.dist(self, point_a, point_b)
#     <a href='file:///home/taco650/miniconda3/lib/python3.9/site-packages/geomstats/geometry/poincare_ball.py?line=250'>251</a> norm_function = 1 + 2 * diff_norm / ((1 - point_a_norm) * (1 - point_b_norm))
#     <a href='file:///home/taco650/miniconda3/lib/python3.9/site-packages/geomstats/geometry/poincare_ball.py?line=252'>253</a> dist = gs.log(norm_function + gs.sqrt(norm_function**2 - 1))
# --> <a href='file:///home/taco650/miniconda3/lib/python3.9/site-packages/geomstats/geometry/poincare_ball.py?line=253'>254</a> dist *= self.scale
#     <a href='file:///home/taco650/miniconda3/lib/python3.9/site-packages/geomstats/geometry/poincare_ball.py?line=254'>255</a> return dist
#
# KeyboardInterrupt:
