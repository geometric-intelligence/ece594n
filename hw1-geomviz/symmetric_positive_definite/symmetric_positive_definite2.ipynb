# %%
import matplotlib.pyplot as plt

import symmetric_positive_definite

import numpy as np
import geomstats.visualization as visualization
from geomstats.geometry.spd_matrices import *
from geomstats.visualization import Ellipses

# %%
spdManifold = SPDMatrices(2)
randomPoints = spdManifold.random_point(n_samples=5)
# plot()

ellipses = visualization.Ellipses()

ellipses.draw_points(points=randomPoints)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.ipynb#ch0000001?line=0'>1</a> spdManifold = SPDMatrices(2)
#       <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.ipynb#ch0000001?line=1'>2</a> randomPoints = spdManifold.random_point(n_samples=5)
#       <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.ipynb#ch0000001?line=2'>3</a> # plot()
#
# NameError: name 'SPDMatrices' is not defined

# %%
randomPoints
#
# Out:
# array([[[ 2.33677527,  0.0568936 ],
#         [ 0.0568936 ,  0.44538732]],
#
#        [[ 1.23527593, -0.21707396],
#         [-0.21707396,  1.14611841]],
#
#        [[ 0.54096052,  0.05765042],
#         [ 0.05765042,  1.3813563 ]],
#
#        ...,
#
#        [[ 1.96814677, -0.31376594],
#         [-0.31376594,  1.10525846]],
#
#        [[ 2.61035734, -0.46641807],
#         [-0.46641807,  0.64304604]],
#
#        [[ 1.58684472,  1.01398464],
#         [ 1.01398464,  1.92177174]]])

# %%
randomPoints.shape
# Out:
# (1000, 2, 2)

# %%
randomPoints[:,0,0].shape
# Out:
# (1000,)

# %%
symmetric_positive_definite.plot2(randomPoints)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.ipynb#ch0000004?line=0'>1</a> symmetric_positive_definite.plot2(randomPoints)
#
# File ~/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.py:19, in plot2(points)
#      <a href='file:///home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.py?line=16'>17</a> ydata = points[:,0,1]
#      <a href='file:///home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.py?line=17'>18</a> zdata = points[:,1,1]
# ---> <a href='file:///home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.py?line=18'>19</a> ax.plot_surface(xdata, ydata, zdata, rstride=1, cstride=1,
#      <a href='file:///home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.py?line=19'>20</a>             cmap='viridis', edgecolor='none')
#      <a href='file:///home/taco650/ECE/ECE194N/ece594n-fork/hw1-geomviz/symmetric_positive_definite/symmetric_positive_definite.py?line=20'>21</a> ax.set_title('surface')
#
# File ~/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=401'>402</a>     deprecation_addendum = (
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=402'>403</a>         f"If any parameter follows {name!r}, they should be passed as "
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=403'>404</a>         f"keyword, not positionally.")
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=404'>405</a>     warn_deprecated(
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=405'>406</a>         since,
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=406'>407</a>         name=repr(name),
#    (...)
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=409'>410</a>                  else deprecation_addendum,
#     <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=410'>411</a>         **kwargs)
# --> <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=411'>412</a> return func(*inner_args, **inner_kwargs)
#
# File ~/ECE/ECE194N/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py:1581, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=1577'>1578</a> had_data = self.has_data()
#    <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=1579'>1580</a> if Z.ndim != 2:
# -> <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=1580'>1581</a>     raise ValueError("Argument Z must be 2-dimensional.")
#    <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=1582'>1583</a> Z = cbook._to_unmasked_float_array(Z)
#    <a href='file:///home/taco650/ECE/ECE194N/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py?line=1583'>1584</a> X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
