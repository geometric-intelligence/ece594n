# %% [markdown]
# # Reproducing the paper: cell states beyond transcriptomics

# %% [markdown]
# Authors: Zheng Xu, Zhiyuan Ren and Xinling Yu

# %% [markdown]
# ## Difficulties

# %% [markdown]
# - All of us have little domain knowledge in cell systems and gene expressions, which makes it very hard for us to understand the paper and read the code.
# - To use the published code to reproduce the results from the beginning, we have to download a very large dataset which is impossible when we don't have such computational resources. Instead, we can just use the collated data from quilt to reproduce the figures.

# %% [markdown]
# ## Timeline

# %% [markdown]
# Sunday
# - 10:00AM - 13:00PM: Read the research paper.
# - 14:00PM - 14:30PM: Download the code and set up the conda environment.
# - 15:00PM - 20:00PM: Try to download the data and use the code followling the guidelines from the github repo.
#
# Monday
# - 15:00PM - 16:00PM: Brainstorm.
# - 16:00PM - 18:00PM: Reproduce figures of the paper using published data and code/notebook.
# - 19:00PM - 23:00PM: Reproduce figures of the paper using published data and code/notebook.

# %% [markdown]
# ## Our repreducing results

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### fig 2(f): Heatmaps from two time points in which individual cells (x axis) have been ranked according to the fraction of the cell area consisting of organized z-disks (yellow).

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams
rcParams['figure.figsize'] = 20 ,5
img_A = mpimg.imread('/Users/xuzheng/Desktop/f2f 1.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f2f.png')
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A)
ax[1].imshow(img_B)

# %% [markdown]
# ### fig 3(E): Plot showing fraction of cell area covered with organized z-disks versus maximum coefficient of variation from Haralick correlation method (see “quantification of global sarcomere alignment” in STAR methods for details) at D18 (blue) and D32 (pink).

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams
rcParams['figure.figsize'] = 18 ,5
img_A = mpimg.imread('/Users/xuzheng/Desktop/f3e 1.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f3e.png')
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A)
ax[1].imshow(img_B)

# %% [markdown]
# ### fig 4(F): Relative contribution of features to the linear regression model used to calculate a cell’s COS.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams
rcParams['figure.figsize'] = 18 ,5
img_A = mpimg.imread('/Users/xuzheng/Desktop/f4f 1.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f4f.png')
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A)
ax[1].imshow(img_B)

# %% [markdown]
# ### fig 5(A): Confusion matrices show concordance between the COS (rounded to nearest discrete value) and include data from both expert annotators for the training set (blue) and test sets (orange and green).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams
rcParams['figure.figsize'] = 18 ,7
img_A = mpimg.imread('/Users/xuzheng/Desktop/f5a-p1.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f5a-p2.png')
img_C = mpimg.imread('/Users/xuzheng/Desktop/f5a-p3.png')
fig, ax = plt.subplots(1,3)
ax[0].imshow(img_A)
ax[1].imshow(img_B)
ax[2].imshow(img_C)

# %% [markdown]
# ### fig 5(B C D): comparing the expert annotations of organization to the COS, comparing the expert annotations of organization to the fraction area organized z-disks and fraction area fibers, showing the distribution of COSs for D18 (blue), D25 (purple), and D32 (pink)

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 20 ,10
img_A = mpimg.imread('/Users/xuzheng/Desktop/f5b.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f5c-p1.png')
img_C = mpimg.imread('/Users/xuzheng/Desktop/f5c-p2.png')
img_D = mpimg.imread('/Users/xuzheng/Desktop/f5d.png')
fig, ax = plt.subplots(1,4)
ax[0].imshow(img_A)
ax[1].imshow(img_B)
ax[2].imshow(img_C)
ax[3].imshow(img_D)

# %%
rcParams['figure.figsize'] = 20 ,8
img_A = mpimg.imread('/Users/xuzheng/Desktop/f5b 1.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f5c.png')
img_C = mpimg.imread('/Users/xuzheng/Desktop/f5d 1.png')
fig, ax = plt.subplots(1,3)
ax[0].imshow(img_A)
ax[1].imshow(img_B)
ax[2].imshow(img_C)

# %% [markdown]
# ### fig 6(B): Box plots showing the bootstrapped Spearman rank correlation between COS and transcript abundance of COL2A1, MYH7, and PLN.

# %%
rcParams['figure.figsize'] = 18 ,5
img_A = mpimg.imread('/Users/xuzheng/Desktop/f6b 1.png')
img_B = mpimg.imread('/Users/xuzheng/Desktop/f6b.png')
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A)
ax[1].imshow(img_B)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - It's very hard to reproduce all the results of this paper from the raw data, but we can just use the collated data(CVS) from quilt to reproduce the figures in the paper.
# - It's hard to use their codebase to conduct new research, the data they provided is very large and the code they provided is not well documented and not flexible. Unlike geomstats, we don't have toy examples to help us understand the problem.
# - It takes much time to understand the paper. We should discuss more with professional people when we are doing interdisciplinary research.
